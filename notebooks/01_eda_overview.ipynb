# %% [markdown]
# # Main Overview Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

repos = pd.read_csv("../data/all_metrics.csv")
ranks = pd.read_csv("../data/search_ranks.csv")
