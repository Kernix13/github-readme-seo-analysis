# %% [markdown]
# # GitHub Explore Ranks Analysis
#
# Find which metrics affect ranking in GitHub Explore search results.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
